# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
data=pd.read_csv("sentiment_analysis.csv ")
print(data)
x=data['text']
y=data['sentiment']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# Out:
#                                 text sentiment
# 0                  I love this movie  positive
# 1            This product is amazing  positive
# 2      Excellent service and support  positive
# 3   I am very happy with the results  positive
# 4          This is the best app ever  positive
# 5       The experience was wonderful  positive
# 6          I really enjoyed the food  positive
# 7    The performance was outstanding  positive
# 8                  This is fantastic  positive
# 9                  Very good quality  positive
# 10               I hate this product  negative
# 11            This movie is terrible  negative
# 12             Worst experience ever  negative
# 13            I am very disappointed  negative
# 14               This app is useless  negative
# 15          The service was horrible  negative
# 16       I will never buy this again  negative
# 17                  Very bad quality  negative
# 18                     This is awful  negative
# 19               The food tasted bad  negative

# %%
vectorizer= TfidfVectorizer()
x_train_vect=vectorizer.fit_transform(x_train)
x_test_vect=vectorizer.transform(x_test)

model=MultinomialNB()
model.fit(x_train_vect,y_train)

y_pred=model.predict(x_test_vect)

accuracy=accuracy_score(y_test,y_pred)
print('accuracy:',accuracy)
# Out:
# accuracy: 0.0

# %%
test=input('enter the text:')
test_vect=vectorizer.transform([test])

predict=model.predict(test_vect)
print('sentimenal:',predict[0])
# Out:
# enter the text: i am bad
# sentimenal: negative
