# %%
text=input("enter the sentance")
words=word_tokenize(text)
print(words)
# Out:
# enter the sentance hello i am jeffin mathew he is good boy
# ['hello', 'i', 'am', 'jeffin', 'mathew', 'he', 'is', 'good', 'boy']

# %%
count=len(words)
print(count)
# Out:
# 9

# %%
stopword=set(stopwords.words('english'))
check= [word for word in words if word not in stopword ]
print(check)
# Out:
# ['hello', 'jeffin', 'mathew', 'good', 'boy']
