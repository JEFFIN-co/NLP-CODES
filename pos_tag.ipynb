# %%
import nltk 
from nltk import word_tokenize,pos_tag

# %%
text=str(input("enter the enter"))
word=word_tokenize(text)
# Out:
# enter the enter hii  i am jeffin guys do ur job and enjoy

# %%
types=pos_tag(word)
print(types)
# Out:
# [('hii', 'NN'), ('i', 'NN'), ('am', 'VBP'), ('jeffin', 'NN'), ('guys', 'NNS'), ('do', 'VBP'), ('ur', 'JJ'), ('job', 'NN'), ('and', 'CC'), ('enjoy', 'VB')]

# %%
no_types=len(types)
print("the no of the types", no_types)
# Out:
# the no of the types 10
